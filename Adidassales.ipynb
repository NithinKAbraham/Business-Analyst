# %% [markdown]
# # ADIDAS-SALE"S  --ANALYSIS-REPORT

# %% [markdown]
# Project Objective:
#
# The objective of this project is to analyze the sales data of Adidas across different regions, states, cities, products, and sales methods to understand the performance of the brand in various aspects. The analysis aims to identify key trends, customer preferences, and profitable avenues for sales to inform strategic decision-making and optimize sales and marketing strategies.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_excel("F:\Business Analyst\Adidas US Sales Datasets.xlsx")

# %%
df
# Out:
#       Unnamed: 0   Unnamed: 1             Unnamed: 2           Unnamed: 3  \
# 0            NaN          NaN  Adidas Sales Database                  NaN
# 1            NaN          NaN                    NaN                  NaN
# 2            NaN          NaN                    NaN                  NaN
# 3            NaN     Retailer            Retailer ID         Invoice Date
# 4            NaN  Foot Locker                1185732  2020-01-01 00:00:00
# ...          ...          ...                    ...                  ...
# 9647         NaN  Foot Locker                1185732  2021-01-24 00:00:00
# 9648         NaN  Foot Locker                1185732  2021-01-24 00:00:00
# 9649         NaN  Foot Locker                1185732  2021-02-22 00:00:00
# 9650         NaN  Foot Locker                1185732  2021-02-22 00:00:00
# 9651         NaN  Foot Locker                1185732  2021-02-22 00:00:00
#
#      Unnamed: 4     Unnamed: 5  Unnamed: 6               Unnamed: 7  \
# ...

# %%
df=df.drop([0,1,2])
df=df.reset_index(drop=True)
df=df.drop(columns=["Unnamed: 0"])
df.head(4)
# Out:
#     Unnamed: 1   Unnamed: 2           Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0     Retailer  Retailer ID         Invoice Date     Region      State
# 1  Foot Locker      1185732  2020-01-01 00:00:00  Northeast   New York
# 2  Foot Locker      1185732  2020-01-02 00:00:00  Northeast   New York
# 3  Foot Locker      1185732  2020-01-03 00:00:00  Northeast   New York
#
#   Unnamed: 6               Unnamed: 7      Unnamed: 8  Unnamed: 9  \
# 0       City                  Product  Price per Unit  Units Sold
# 1   New York    Men's Street Footwear              50        1200
# 2   New York  Men's Athletic Footwear              50        1000
# 3   New York  Women's Street Footwear              40        1000
#
#    Unnamed: 10       Unnamed: 11       Unnamed: 12   Unnamed: 13
# 0  Total Sales  Operating Profit  Operating Margin  Sales Method
# 1       600000            300000               0.5      In-store
# 2       500000            150000               0.3      In-store
# ...

# %%
df.columns=df.iloc[0]
df=df.drop(0)
df=df.reset_index(drop=True)
df.head()
# Out:
# 0     Retailer Retailer ID         Invoice Date     Region     State  \
# 0  Foot Locker     1185732  2020-01-01 00:00:00  Northeast  New York
# 1  Foot Locker     1185732  2020-01-02 00:00:00  Northeast  New York
# 2  Foot Locker     1185732  2020-01-03 00:00:00  Northeast  New York
# 3  Foot Locker     1185732  2020-01-04 00:00:00  Northeast  New York
# 4  Foot Locker     1185732  2020-01-05 00:00:00  Northeast  New York
#
# 0      City                    Product Price per Unit Units Sold Total Sales  \
# 0  New York      Men's Street Footwear             50       1200      600000
# 1  New York    Men's Athletic Footwear             50       1000      500000
# 2  New York    Women's Street Footwear             40       1000      400000
# 3  New York  Women's Athletic Footwear             45        850      382500
# 4  New York              Men's Apparel             60        900      540000
#
# 0 Operating Profit Operating Margin Sales Method
# ...

# %%
df.to_csv("adidassalesdata.csv")

# %%
adidassales=df
adidassales.head()
# Out:
# 0     Retailer Retailer ID         Invoice Date     Region     State  \
# 0  Foot Locker     1185732  2020-01-01 00:00:00  Northeast  New York
# 1  Foot Locker     1185732  2020-01-02 00:00:00  Northeast  New York
# 2  Foot Locker     1185732  2020-01-03 00:00:00  Northeast  New York
# 3  Foot Locker     1185732  2020-01-04 00:00:00  Northeast  New York
# 4  Foot Locker     1185732  2020-01-05 00:00:00  Northeast  New York
#
# 0      City                    Product Price per Unit Units Sold Total Sales  \
# 0  New York      Men's Street Footwear             50       1200      600000
# 1  New York    Men's Athletic Footwear             50       1000      500000
# 2  New York    Women's Street Footwear             40       1000      400000
# 3  New York  Women's Athletic Footwear             45        850      382500
# 4  New York              Men's Apparel             60        900      540000
#
# 0 Operating Profit Operating Margin Sales Method
# ...

# %%
adidassales.tail()
# Out:
# 0        Retailer Retailer ID         Invoice Date     Region          State  \
# 9643  Foot Locker     1185732  2021-01-24 00:00:00  Northeast  New Hampshire
# 9644  Foot Locker     1185732  2021-01-24 00:00:00  Northeast  New Hampshire
# 9645  Foot Locker     1185732  2021-02-22 00:00:00  Northeast  New Hampshire
# 9646  Foot Locker     1185732  2021-02-22 00:00:00  Northeast  New Hampshire
# 9647  Foot Locker     1185732  2021-02-22 00:00:00  Northeast  New Hampshire
#
# 0           City                  Product Price per Unit Units Sold  \
# 9643  Manchester            Men's Apparel             50         64
# 9644  Manchester          Women's Apparel             41        105
# 9645  Manchester    Men's Street Footwear             41        184
# 9646  Manchester  Men's Athletic Footwear             42         70
# 9647  Manchester  Women's Street Footwear             29         83
#
# 0    Total Sales Operating Profit Operating Margin Sales Method
# ...

# %%
adidassales.sample(4)
# Out:
# 0          Retailer Retailer ID         Invoice Date     Region        State  \
# 8529    Foot Locker     1128299  2021-08-24 00:00:00  Southeast     Virginia
# 5251  Sports Direct     1128299  2021-01-17 00:00:00       West       Hawaii
# 9293  Sports Direct     1185732  2021-03-03 00:00:00  Northeast  Connecticut
# 6022    Foot Locker     1128299  2021-10-23 00:00:00       West      Arizona
#
# 0         City                  Product Price per Unit Units Sold Total Sales  \
# 8529  Richmond    Men's Street Footwear             67        272       18224
# 5251  Honolulu            Men's Apparel             54         68        3672
# 9293  Hartford  Women's Street Footwear             23         75        1725
# 6022   Phoenix  Men's Athletic Footwear             47        145        6815
#
# 0    Operating Profit Operating Margin Sales Method
# 8529           7289.6              0.4       Outlet
# 5251           1101.6              0.3       Online
# ...

# %%
adidassales.shape
# Out:
# (9648, 13)

# %%
columns=[]
for i in adidassales.columns:
    columns.append(i)
print(columns)
# Out:
# ['Retailer', 'Retailer ID', 'Invoice Date', 'Region', 'State', 'City', 'Product', 'Price per Unit', 'Units Sold', 'Total Sales', 'Operating Profit', 'Operating Margin', 'Sales Method']

# %%
adidassales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 0 to 9647
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9648 non-null   object
#  1   Retailer ID       9648 non-null   object
#  2   Invoice Date      9648 non-null   object
#  3   Region            9648 non-null   object
#  4   State             9648 non-null   object
#  5   City              9648 non-null   object
#  6   Product           9648 non-null   object
#  7   Price per Unit    9648 non-null   object
#  8   Units Sold        9648 non-null   object
#  9   Total Sales       9648 non-null   object
#  10  Operating Profit  9648 non-null   object
#  11  Operating Margin  9648 non-null   object
#  12  Sales Method      9648 non-null   object
# dtypes: object(13)
# memory usage: 980.0+ KB

# %%
adidassales.describe().T
# Out:
#                    count unique                    top    freq
# 0
# Retailer            9648      6            Foot Locker    2637
# Retailer ID         9648      4                1185732    5265
# Invoice Date        9648    724    2021-01-17 00:00:00      77
# Region              9648      5                   West    2448
# State               9648     50             California     432
# City                9648     52               Portland     360
# Product             9648      6  Men's Street Footwear    1610
# Price per Unit      9648    146                     50     557
# Units Sold          9648    361                    225     207
# Total Sales         9648   3512                 100000      52
# Operating Profit    9648   6510                  21000      34
# Operating Margin  9648.0  127.0                   0.35  1229.0
# Sales Method        9648      3                 Online    4889

# %%
adidassales.describe(include="object").T
# Out:
#                    count unique                    top    freq
# 0
# Retailer            9648      6            Foot Locker    2637
# Retailer ID         9648      4                1185732    5265
# Invoice Date        9648    724    2021-01-17 00:00:00      77
# Region              9648      5                   West    2448
# State               9648     50             California     432
# City                9648     52               Portland     360
# Product             9648      6  Men's Street Footwear    1610
# Price per Unit      9648    146                     50     557
# Units Sold          9648    361                    225     207
# Total Sales         9648   3512                 100000      52
# Operating Profit    9648   6510                  21000      34
# Operating Margin  9648.0  127.0                   0.35  1229.0
# Sales Method        9648      3                 Online    4889

# %%
adidassales.dtypes
# Out:
# 0
# Retailer            object
# Retailer ID         object
# Invoice Date        object
# Region              object
# State               object
# City                object
# Product             object
# Price per Unit      object
# Units Sold          object
# Total Sales         object
# Operating Profit    object
# Operating Margin    object
# Sales Method        object
# dtype: object

# %%
adidassales.isna().sum()
# Out:
# 0
# Retailer            0
# Retailer ID         0
# Invoice Date        0
# Region              0
# State               0
# City                0
# Product             0
# Price per Unit      0
# Units Sold          0
# Total Sales         0
# Operating Profit    0
# Operating Margin    0
# Sales Method        0
# dtype: int64

# %%
adidassales.duplicated().sum()
# Out:
# 0

# %%
adidassales["Invoice Date"]=pd.to_datetime(adidassales["Invoice Date"])
adidassales["year"]=adidassales["Invoice Date"].dt.year
adidassales["month"]=adidassales["Invoice Date"].dt.month

# %%
adidassales
# Out:
# 0        Retailer Retailer ID Invoice Date     Region          State  \
# 0     Foot Locker     1185732   2020-01-01  Northeast       New York
# 1     Foot Locker     1185732   2020-01-02  Northeast       New York
# 2     Foot Locker     1185732   2020-01-03  Northeast       New York
# 3     Foot Locker     1185732   2020-01-04  Northeast       New York
# 4     Foot Locker     1185732   2020-01-05  Northeast       New York
# ...           ...         ...          ...        ...            ...
# 9643  Foot Locker     1185732   2021-01-24  Northeast  New Hampshire
# 9644  Foot Locker     1185732   2021-01-24  Northeast  New Hampshire
# 9645  Foot Locker     1185732   2021-02-22  Northeast  New Hampshire
# 9646  Foot Locker     1185732   2021-02-22  Northeast  New Hampshire
# 9647  Foot Locker     1185732   2021-02-22  Northeast  New Hampshire
#
# 0           City                    Product Price per Unit Units Sold  \
# ...

# %%
# Group by month and calculate total sales for each month
monthly_sales = adidassales.groupby(adidassales['Invoice Date'].dt.to_period('Y'))['Total Sales'].sum()

# Plot the sales trends
plt.figure(figsize=(10, 6))
monthly_sales.plot(kind='line', marker='o', color='blue')
plt.title('Monthly Sales Trends')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.grid(True)
plt.show()

# %% [markdown]
# To conduct market analysis using the columns you provided, you can perform various types of analysis such as sales trends, geographical analysis, product performance analysis, profitability analysis, and sales channel analysis. Here's how you can approach it:
#
# Sales Trends Analysis:
# Plot the total sales over time to identify trends and seasonality.
# Calculate monthly or quarterly sales growth rates to understand the sales trajectory.
# Analyze the impact of external factors (e.g., marketing campaigns, economic conditions) on sales trends.
# Geographical Analysis:
# Group sales data by region, state, or city to identify high-performing and low-performing areas.
# Compare sales performance across different geographical regions.
# Analyze regional trends and patterns to understand market dynamics.
# Product Performance Analysis:
# Analyze sales performance for each product category or individual products.
# Identify best-selling products and analyze their contribution to total sales.
# Evaluate the profitability of each product category to prioritize resource allocation.
# Profitability Analysis:
# Calculate profit margins for different products, regions, or sales channels.
# Identify areas with high profitability and areas that may require optimization.
# Analyze factors influencing profitability, such as pricing strategy and operating costs.
# Sales Channel Analysis:
# Compare sales performance across different sales channels (e.g., in-store vs. online).
# Analyze the effectiveness of each sales channel in reaching target customers.
# Identify opportunities to optimize sales channels and improve overall sales performance.
# You can use various data visualization techniques such as line charts, bar charts, and pie charts to visualize the analysis results. Additionally, statistical analysis and machine learning algorithms can

# %%
# Group by month and calculate total sales for each month
monthly_sales = adidassales.groupby(adidassales['Invoice Date'].dt.to_period('M'))['Total Sales'].sum()

# Plot the sales trends
plt.figure(figsize=(10, 6))
monthly_sales.plot(kind='line', marker='o', color='blue')
plt.title('Monthly Sales Trends')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you already have a DataFrame named 'adidassales' containing the sales data

# Assuming you have defined monthly_sales as mentioned before
monthly_sales = adidassales.groupby('Region')['Total Sales'].sum().sort_values(ascending=False)

# Define colors for each region
colors = ['skyblue', 'orange', 'green', 'red', 'purple']  # Add more colors if you have more regions

# Plot the sales distribution by region with different colors for each bar
plt.figure(figsize=(10, 6))
monthly_sales.plot(kind='bar', color=colors)
plt.title('Total Sales by Region')
plt.xlabel('Region')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %%
state_sales = adidassales.groupby('State')['Total Sales'].sum().sort_values(ascending=False).head(10)  
print("Top 10 States by Total Sales:")
print(state_sales)
# Out:
# Top 10 States by Total Sales:
# State
# New York          64229039.0
# California        60174133.0
# Florida           59283714.0
# Texas             46359746.0
# South Carolina    29285637.0
# Washington        26330718.0
# North Carolina    23956531.0
# Louisiana         23750781.0
# Hawaii            22282457.0
# Virginia          21575040.0
# Name: Total Sales, dtype: object

# %% [markdown]
# New York: With total sales of $64,229,039, New York is the state with the highest revenue generated from Adidas sales among the top 10 states.
#
# California: Following closely behind, California generated $60,174,133 in total sales, making it the second-highest revenue-generating state.
#
# Florida: Florida ranks third with total sales amounting to $59,283,714.
#
# Texas: Texas follows with total sales of $46,359,746.
#
# South Carolina: South Carolina ranks fifth with total sales of $29,285,637.
#
# Washington: Washington generated $26,330,718 in total sales, securing the sixth position.
#
# North Carolina: North Carolina follows with total sales of $23,956,531.
#
# Louisiana: Louisiana generated $23,750,781 in total sales, placing it in the eighth position.
#
# Hawaii: Hawaii ranks ninth with total sales amounting to $22,282,457.
#
# Virginia: Finally, Virginia completes the top 10 list with total sales of $21,575,040.

# %%
city_sales = adidassales.groupby('City')['Total Sales'].sum().sort_values(ascending=False).head(10)  
print("\nTop 10 Cities by Total Sales:")
print(city_sales)
# Out:
# Top 10 Cities by Total Sales:
# City
# Charleston       39974797.0
# New York         39801235.0
# San Francisco    34539220.0
# Miami            31600863.0
# Portland         30545652.0
# Orlando          27682851.0
# Seattle          26330718.0
# Los Angeles      25634913.0
# Houston          25456882.0
# Albany           24427804.0
# Name: Total Sales, dtype: object

# %% [markdown]
# Charleston: Leading the list, Charleston generated total sales of $39,974,797, making it the city with the highest revenue from Adidas sales among the top 10 cities.
#
# New York: Following closely behind, New York City generated $39,801,235 in total sales, securing the second-highest position.
#
# San Francisco: San Francisco ranks third with total sales amounting to $34,539,220.
#
# Miami: Miami follows with total sales of $31,600,863.
#
# Portland: Portland generated $30,545,652 in total sales, placing it in the fifth position.
#
# Orlando: Orlando ranks sixth with total sales of $27,682,851.
#
# Seattle: Seattle generated $26,330,718 in total sales, securing the seventh position.
#
# Los Angeles: Los Angeles follows with total sales of $25,634,913.
#
# Houston: Houston ranks ninth with total sales amounting to $25,456,882.
#
# Albany: Finally, Albany completes the top 10 list with total sales of $24,427,804.

# %%
adidassales['Profit Margin'] = adidassales.apply(lambda row: (row['Operating Profit'] / row['Total Sales']) * 100 if row['Total Sales'] != 0 else 0, axis=1)
product_profitability = adidassales.groupby('Product')['Profit Margin'].mean().sort_values(ascending=False)
region_profitability = adidassales.groupby('Region')['Profit Margin'].mean().sort_values(ascending=False)
sales_channel_profitability = adidassales.groupby('Sales Method')['Profit Margin'].mean().sort_values(ascending=False)

# %%
print("Top 5 Profitable Products:")
print(product_profitability.head(5))
# Out:
# Top 5 Profitable Products:
# Product
# Men's Street Footwear        44.613043
# Women's Apparel              44.131841
# Women's Athletic Footwear    42.318804
# Men's Apparel                41.322540
# Women's Street Footwear      41.019900
# Name: Profit Margin, dtype: float64

# %% [markdown]
# Men's Street Footwear: This product category yields the highest operating profit margin of approximately 44.61%. This indicates that for every dollar generated in sales of men's street footwear, around 44.61 cents contribute to the operating profit.
#
# Women's Apparel: Following closely, women's apparel boasts an operating profit margin of about 44.13%. It's the second-most profitable product category for Adidas.
#
# Women's Athletic Footwear: With an operating profit margin of around 42.32%, women's athletic footwear secures the third position in terms of profitability.
#
# Men's Apparel: Men's apparel follows with an operating profit margin of approximately 41.32%, making it the fourth-most profitable product category for Adidas.
#
# Women's Street Footwear: Lastly, women's street footwear holds an operating profit margin of about 41.02%, ranking fifth in profitability among Adidas products.

# %%
print("\nBottom 3 Profitable Products:")
print(product_profitability.tail(3))
# Out:
# Bottom 3 Profitable Products:
# Product
# Men's Apparel              41.322540
# Women's Street Footwear    41.019900
# Men's Athletic Footwear    40.270186
# Name: Profit Margin, dtype: float64

# %% [markdown]
# Men's Apparel: This product category has the highest operating profit margin among the bottom 3, with approximately 41.32%. Despite being among the least profitable for Adidas, men's apparel still contributes positively to the operating profit margin.
#
# Women's Street Footwear: Following closely behind, women's street footwear has an operating profit margin of about 41.02%. While still contributing to profit, it falls into the bottom 3 in terms of profitability among Adidas products.
#
# Men's Athletic Footwear: With an operating profit margin of approximately 40.27%, men's athletic footwear ranks as the least profitable among the bottom 3 Adidas products.

# %%
print("\nTop 5 Profitable Regions:")
print(region_profitability.head(5))
# Out:
# Top 5 Profitable Regions:
# Region
# South        46.689815
# Midwest      43.426816
# Southeast    41.916667
# Northeast    41.045034
# West         39.669118
# Name: Profit Margin, dtype: float64

# %% [markdown]
# South: This region has the highest operating profit margin among the top 5, at approximately 46.69%. It indicates that, on average, Adidas operations in the South are particularly profitable.
#
# Midwest: Following closely, the Midwest region boasts an operating profit margin of about 43.43%, securing the second-highest position in terms of profitability for Adidas.
#
# Southeast: With an operating profit margin of approximately 41.92%, the Southeast region ranks third in profitability among the top 5 regions for Adidas.
#
# Northeast: The Northeast region follows with an operating profit margin of about 41.05%, making it the fourth-most profitable region for Adidas.
#
# West: Lastly, the West region holds an operating profit margin of approximately 39.67%, ranking fifth in profitability among the top 5 regions for Adidas.

# %%
print("\nBottom 53Profitable Regions:")
print(region_profitability.tail(3))
# Out:
# Bottom 53Profitable Regions:
# Region
# Southeast    41.916667
# Northeast    41.045034
# West         39.669118
# Name: Profit Margin, dtype: float64

# %%
print("\nTop 5 Profitable Sales Channels:")
print(sales_channel_profitability.head(3))
# Out:
# Top 5 Profitable Sales Channels:
# Sales Method
# Online      46.393127
# Outlet      39.461080
# In-store    35.612069
# Name: Profit Margin, dtype: float64

# %%
print("\nBottom 5 Profitable Sales Channels:")
print(sales_channel_profitability.tail(3))
# Out:
# Bottom 5 Profitable Sales Channels:
# Sales Method
# Online      46.393127
# Outlet      39.461080
# In-store    35.612069
# Name: Profit Margin, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Convert 'Invoice Date' column to datetime if it's not already in datetime format
adidassales['Invoice Date'] = pd.to_datetime(adidassales['Invoice Date'])

# %%
# Descriptive Analysis
sales_method_summary = adidassales.groupby('Sales Method').agg({
    'Total Sales': 'sum',
    'Operating Profit': 'sum',
    'Units Sold': 'sum'
}).reset_index()

# %%
print("Sales Method Summary:")
print(sales_method_summary)
# Out:
# Sales Method Summary:
# 0 Sales Method  Total Sales Operating Profit Units Sold
# 0     In-store  356643750.0      127591287.5     689990
# 1       Online  247672882.0      96555176.47     939093
# 2       Outlet  295585493.0     107988297.48     849778

# %%
# Visualization
plt.figure(figsize=(10, 6))
sns.barplot(x='Sales Method', y='Total Sales', data=adidassales, estimator=sum)
plt.title('Total Sales by Sales Method')
plt.xlabel('Sales Method')
plt.ylabel('Total Sales')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='Invoice Date', y='Total Sales', hue='Sales Method', data=adidassales)
plt.title('Total Sales Trend by Sales Method')
plt.xlabel('Invoice Date')
plt.ylabel('Total Sales')
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Lenovo\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Customer Analysis
customer_preferences = adidassales.groupby(['Sales Method', 'Retailer']).size().unstack(fill_value=0)
print("Customer Preferences:")
print(customer_preferences)
# Out:
# Customer Preferences:
# Retailer      Amazon  Foot Locker  Kohl's  Sports Direct  Walmart  West Gear
# Sales Method
# In-store         118          449     144            293       37        699
# Online           540         1395     576            995      288       1095
# Outlet           291          793     310            744      301        580

# %% [markdown]
# For each combination of retailer and sales method, the numbers represent the quantity of Adidas products sold through that particular retailer and sales method. For instance, the value of 118 under "Amazon" and "In-store" means that 118 units of Adidas products were sold through Amazon's physical stores.

# %%
# Profitability Analysis
profitability_analysis = adidassales.groupby('Sales Method').agg({
    'Operating Profit': 'sum',
    'Operating Margin': 'mean'
}).reset_index()

print("Profitability Analysis:")
print(profitability_analysis)
# Out:
# Profitability Analysis:
# 0 Sales Method Operating Profit Operating Margin
# 0     In-store      127591287.5         0.356121
# 1       Online      96555176.47         0.464152
# 2       Outlet     107988297.48         0.394876

# %% [markdown]
# Sales Method: In-store, Online, Outlet.
# Operating Profit: The total operating profit generated through each sales method. For instance, sales through in-store channels generated approximately $127,591,287.50 in operating profit.
#
# Operating Margin: The operating margin, expressed as a decimal, represents the proportion of operating profit relative to total sales revenue. For example, the operating margin for online sales is approximately 0.464152, indicating that about 46.42% of total sales revenue from online channels contributes to operating profit.

# %%
# Market Research
sales_method_distribution = adidassales['Sales Method'].value_counts(normalize=True)
print("Sales Method Distribution:")
print(sales_method_distribution)
# Out:
# Sales Method Distribution:
# Sales Method
# Online      0.506737
# Outlet      0.312915
# In-store    0.180348
# Name: proportion, dtype: float64

# %% [markdown]
# Sales Method: Online, Outlet, In-store.
#
# Distribution: The percentage of total sales attributed to each sales method. For example:
#
# Online sales account for approximately 50.67% (0.506737) of total Adidas sales.
#
# Outlet sales represent around 31.29% (0.312915) of total sales.
#
# In-store sales make up roughly 18.03% (0.180348) of total sales

# %% [markdown]
# # Conclusions:

# %% [markdown]
# 1.Regional Performance:
#
#     The South region emerges as the most profitable, followed by the Midwest, Southeast, Northeast, and West.
#
#     Further investigation into why the South region outperforms others can provide insights into regional consumer behavior and preferences.

# %% [markdown]
# 2.State and City Insights:
#
#     New York, California, and Florida are the top three states by total sales, with Charleston, New York, and San Francisco leading in city-wise sales.
#
#     Understanding the demographics and market dynamics in these regions can help tailor marketing efforts for better sales outcomes.

# %% [markdown]
# 3.Product Performance:
#
#     Men's Street Footwear is the most profitable product, followed by Women's Apparel and Women's Athletic Footwear.
#     Leveraging the popularity of these products can drive overall sales and profitability.

# %% [markdown]
# 4.Sales Channel Analysis:
#
#     Online sales have the highest profitability and proportion of total sales, indicating a shift in consumer behavior towards e-commerce.
#     In-store sales have the lowest profitability but still contribute significantly to total sales, suggesting the importance of maintaining a physical     retail presence.

# %% [markdown]
# 5.Customer Preferences:
#
#     Amazon and Foot Locker are the preferred retailers across all sales methods, indicating strong brand loyalty and market presence.
#
#     Tailoring marketing strategies and partnerships with these retailers can further enhance sales.
